# %% [markdown]
# ```
# # -*- coding: utf-8 -*-
# import psycopg2
# import datetime
#
# # db = psycopg2.connect(database="gamesdk_userlog", password="XbNa2%40J-oXVMeyE6Da", host="172.17.0.16", port="5432")
# db = psycopg2.connect("postgresql://xwgame:XbNa2%40J-oXVMeyE6Da@172.17.0.16:5432/gamesdk_userlog")
# db_cursor = db.cursor()
#
# def get_user_log(user_id, os_type="android"):
#     date = datetime.date.today()
#     count = 0
#     game_list = []
#     record = {}
#     while count < 30:
#         # 对日期进行字符处理
#         str_date = str(date)[0:4] + str(date)[5:7] + str(date)[8:10]
#         table = 'log_action_userlogin_'+ str_date
#
#         sql = (
#             "SELECT from_game, reg_date "
#             "FROM {table} "
#             "WHERE user_id = {id} AND from_os = '{os}' "
#             "ORDER BY login_time;"
#         ).format(table=table, id=user_id, os=os_type)
#
#         # db_cursor.execute(sql, {"table": table, "user_id": user_id, "os_type": os_type})
#         count += 1
#         db_cursor.execute(sql)
#         for from_game, reg_date in db_cursor.fetchall():
#             print from_game
#             game_list.append(from_game)
#             # 截止到注册时间
#             if date < reg_date:
#                 count = 7
#                 break
#
#         date = date - datetime.timedelta(days=1)
#
#     print game_list
#     return game_list
#
# if __name__ == "__main__":
#     get_user_log(210448846)
#
# ```
# 这个Demo是db_cursor.fetchall()可以正确输出数据。
# 但是在下面的例子中却是空的，
# ```
#         db_cursor.execute(sql)
#         if len(db_cursor.fetchall()):
#             print type(db_cursor.fetchall())
#             print db_cursor.fetchall()
#
#         count += 1
#         for from_game, reg_date in db_cursor.fetchall():
#             print from_game
# ```
# 查了一下资料，好像是db_cursor游标在执行完查询后，不可以进行其他操作（len,print）。其他操作会更改db_cursor对象。
