# %% [markdown]
# # 使用Jupyter 来记录《数据结构复习指导——王道论坛》的知识点，要点，难点。
# <br>
# 以下是文件整个目录结构中的一些规范:
# ### 文件命名规范
#
# ```
# 1.0纲要
# 1.1数据结构的基本概念
# (不使用3级目录)
# ```
#
#
# ### markdown 格式规范
# 0纲要
#
# ```
# ### 复习要点
# 1. 数据结构相关的概念和术语
# 2. 数据结构的三要素：逻辑结构、物理结构和数据运算
# 3. 算法的时间复杂度和空间复杂度的分析和计算
#
# ### 目标：初步了解数据结构的基本内容和基本方法，分析算法的时间复杂度和空间复杂度是重点。
# ```
#
# 1章节内容
#
# - 小标题
# ```
# #### 1.  基本概念和术语
# ```
#
# - 概念
# ```
# ##### 数据
# 数据是信息的载体，是描述客观事物属性的数、字符以及能够输入到计算机中并被计算机程序识别和处理的符号的集合。
# ```
#
# - 加粗
# ```
# **强调**
# ```
#
# - 表格
# ```
# |结构|关系|
# |---|---|
# |集合|结构中的数据元素之间除了**‘同属于一个集合’**的关系外，没有其他关系|
# |线性结构|结构中的数据元素之间只存在**一对一**关系|
# |树形关系|结构中的数据元素之间存在**一对多**关系|
# |图状结构|结构中的数据元素之间存在**多对多**关系|
# ```
