# %% [markdown]
# # <center>Markdown语法</center>

# %% [markdown]
# ## 一、标题
#
# ```
# # 这是一级标题
# ## 这是二级标题
# ### 这是三级标题
# #### 这是四级标题
# ##### 这是五级标题
# ###### 这是六级标题
# ```
#
# # 这是一级标题
# ## 这是二级标题
# ### 这是三级标题
# #### 这是四级标题
# ##### 这是五级标题
# ###### 这是六级标题

# %% [markdown]
# ## 二、字体
# ```
# **这是加粗的文字**
# *这是倾斜的文字*
# ***这是斜体加粗的文字***
# ~~这是加删除线的文字~~
# ```
#
# **这是加粗的文字**<br>
# *这是倾斜的文字*<br>
# ***这是斜体加粗的文字***<br>
# ~~这是加删除线的文字~~<br>

# %% [markdown]
# **补充**
#
# 对于标准的markdown文本，是不支持对齐的。还好markdown支持html语言，所以我们采用html语法格式即可。
#
# 1. 文字的居中
# ```
# <center>这一行需要居中</center>
# ```
# <center>这一行需要居中</center>
#
# 也可以搭配 其他标签一同使用,部分双侧标签(倾斜标签，代码标签)无效。
#
# ```
# *** <center>这一行需要居中</center> ***
# ```
# *** <center>这一行需要居中</center> ***
#
# ```
# #### <center>这一行需要居中</center>
# ```
# #### <center>这一行需要居中</center>
#
# 2. 字体更换
# ```
# <font face="黑体">我是黑体字</font>
# ```
# <font face="黑体">我是黑体字</font>
#
# 3. 大小更换
# ```
# <font face="黑体" size=10>我是黑体字</font>
# ```
# <font face="黑体" size=10>我是10号黑体字</font>
#
# 4. 颜色替换
# ```
# <font color=red size=10>颜色</font>
# ```
# <font color=red size=10>颜色</font>

# %% [markdown]
# ## 三、 引用
# 在引用的文字前加>即可。引用也可以嵌套，如加两个>>三个>>>n个...
# ```
# >这是引用的内容
# >>这是引用的内容
# >>>>>>>>>>这是引用的内容
# ```
# >这是引用的内容
# >>这是引用的内容
# >>>这是引用的内容

# %% [markdown]
# ## 四、分割线
# 三个或者三个以上的 - 或者 * 都可以。
# ```
# ---
# ----
# ***
# *****
# ```
#
# ---
#
# ----
#
# ***
#
# *****

# %% [markdown]
# ### 五、图片
# 当需要在某些地方插入图片时，使用
#
# ```
# ![图片alt](图片地址 ''图片title'')
#
# 图片alt就是显示在图片下面的文字，相当于对图片内容的解释。
# 图片title是图片的标题，当鼠标移到图片上时显示的内容。title可加可不加
# ```
#
# !['重庆邮电大学'](https://note.youdao.com/yws/api/personal/file/2B4C66A2E7F84230AB674511BA1409A2?method=download&shareKey=7f776252e878141b5948cfb7c0759822 "我i重邮")

# %% [markdown]
# ### 六、超链接
#
# ```
# [超链接名](超链接地址 "超链接title")
# title可加可不加
# ```
#
# [简书](http://jianshu.com)<br>
# [百度](http://baidu.com)

# %% [markdown]
# ### 七、列表
# 无序列表用 - + * 任何一种都可以
# ```
# - 列表内容
# + 列表内容
# * 列表内容
# ```
# **注：**- + * 跟内容之间都要有一个空格
#
# - 列表内容
# + 列表内容
# * 列表内容
#
# 有序列表
# ```
# 1. 列表内容
# 2. 列表内容
# 3. 列表内容
# ```
#
# 1. 列表内容
# 2. 列表内容
# 3. 列表内容
#
#
# 列表嵌套
# 上一级和下一级之间敲三个空格即可
# ```
# 1. 一级有序列表
#    . 二级无序列表
#    . 二级无序列表
#    . 二级无序列表
# 2. 一级有序列表
# ```
#
# 1. 一级有序列表
#    . 二级无序列表
#    . 二级无序列表
#    . 二级无序列表
# 2. 一级有序列表

# %% [markdown]
# ### 八、表格
# ```
# |表头|表头|表头|
# |---|:--:|---:|
# |内容|内容|内容|
# |内容|内容|内容|
# ```
# **注:**
# 第二行分割表头和内容。
# -有一个就行，为了对齐，多加了几个文字默认居左
# -两边加：表示文字居中
# -右边加：表示文字居右
#
# |表头(居左)|表头(居中)|表头(居右)|
# |---|:--:|---:|
# |内容|内容|内容|
# |内容|内容|内容|

# %% [markdown]
# ### 九、代码
#
# 单行代码：代码之间分别用一个反引号包起来
#
# `代码`
#
# 代码块：代码之间分别用三个反引号包起来，且两边的反引号单独占一行
#
# ```
#   代码...
#   代码...
#   代码...
# ```
